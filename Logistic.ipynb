# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mat
import seaborn as sb
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
dataset=pd.DataFrame(pd.read_csv("E:\\Study\\AIDS\\DS\\ML\\placement.csv"))
dataset.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
dataset.drop(columns=["Unnamed: 0"],inplace=True)
dataset.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
x=dataset.iloc[:,:-1]
y=dataset["placement"]
print(y)
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
sb.scatterplot(data=dataset,x=dataset["cgpa"],y=dataset["iq"],hue="placement")
mat.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=70)
x_test.head()
# Out:
#     cgpa     iq
# 81   5.4  107.0
# 43   6.8  141.0
# 88   4.4  149.0
# 32   7.0  139.0
# 50   3.5  233.0

# %%
lr=LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 95.0

# %%
lr.predict([[6.8,123]])
# Out:
# c:\Users\huzef\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=lr)
mat.show()
# Out:
# c:\Users\huzef\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
